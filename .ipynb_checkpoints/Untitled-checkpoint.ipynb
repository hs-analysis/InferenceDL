# %%
import os
from comdl.apis.train import MMDetTrainer, get_configs
from comdl.apis.inference import InferenceModel
from comdl.utils.train_utils import is_key_present, add_key
import numpy as np
import cv2
import torch
# %load_ext autoreload
# %autoreload 2

# %%
import torch

# %%
m = torch.load(r"D:\Hsa\temp\custom_models\verified_models\Custom - GlomeruliNeuesFramework\instance_seg\001.pt")
m['custom_data'] = {'structure_indices': [2],
 'image_size': 2048,
 'modeltype': 'instance segmentation',
 'object_based': False,
 'physical_tile_size': (0.0, 0.0),
 'project_type': 'dummy',
 'pyramid_level': -1,
 'datetime': '14/12/2021 11:49',
 'structures': 'Blutzelle',
 'objects_count': 3606,
 'model': 'maskrcnn',
 'files': {'File': ['14.1.jpg', '15.1.jpg'], 'Scene': [1, 1]}}
torch.save(m, "002.pt")

# %%
torch.load(r"D:\Hsa\temp\custom_models\verified_models\Custom - glom\instance_seg\001.pt")['custom_data']

# %%
get_configs()['swin']

# %%
os.path.join("/".join(mmdet.__file__.split("\\")[:-1]),".mim", "configs")

# %%
import mmdet.core

# %%
base_config = list(filter(lambda x:"_l_" in x, get_configs()["yolox"]))[0]

# %%
base_config

# %%
nc = 1
base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\.mim\\configs\\detectors\\detectors_htc_r50_1x_coco.py'
#base_config=r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\configs\\yolox\\yolox_m_8x8_300e_coco.py'
#base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\configs\\mask_rcnn\\mask_rcnn_r50_fpn_1x_coco.py'
#base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\configs\\faster_rcnn\\faster_rcnn_r50_fpn_1x_coco.py'
#base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\configs\\detr\\detr_r50_8x2_150e_coco.py'
#base_config = r'C:/Users/phili/miniconda3/envs/mm/lib/site-packages/mmdet\\.mim\\configs\\cascade_rcnn\\cascade_mask_rcnn_x101_32x4d_fpn_1x_coco.py'
#base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\.mim\\configs\\faster_rcnn\\faster_rcnn_r50_fpn_1x_coco.py'
#base_config = r'C:/Users/phili/miniconda3/lib/site-packages/mmdet\\.mim\\configs\\yolox\\yolox_m_8x8_300e_coco.py'
#base_config = list(filter(lambda x:"r50_fpn_1x_coco" in x, get_configs()["mask_rcnn"]))[0]
#base_config = list(filter(lambda x:"_l_" in x, get_configs()["yolox"]))[0]
base_config = get_configs()['swin'][3]
work_dir = r"F:\source\repos\InferenceDL\Exp"
batch_size = 2
workers = 2
dataroot = r"F:\source\repos\Daten\Glomeruli\trainer"
# dataroot = r"F:\source\repos\Daten\Erethorzyten"
# dataroot = r"F:\source\repos\Daten\TubulusMMDet"
# dataroot = r"F:\source\repos\Daten\Her2Final"

#load_from = r"F:\source\repos\InferenceDL\Exp\epoch_20.pth"
load_from = None
#load_from = r"F:\downloads\yolox_l_8x8_300e_coco_20211126_140236-d3bd2b23.pth"
#load_from = r"D:\Hsa\temp\custom_models\verified_models\Custom - GlomeruliNeuesFramework\instance_seg\001.pt"
#resume_from = r"F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_16.pth"
load_from = r"F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_37.pth"
img_scale = (800, 1333)
#img_scale = (640, 640)



#img_scale=(640,640)
# trainer.cfg.lr_config = dict(
#     policy='CosineAnnealing', # The policy of scheduler, also support CosineAnnealing, Cyclic, etc. Refer to details of supported LrUpdater from https://github.com/open-mmlab/mmcv/blob/master/mmcv/runner/hooks/lr_updater.py#L9.
#     by_epoch=False,
#     warmup='linear', # The warmup policy, also support `exp` and `constant`.
#     warmup_iters=500, # The number of iterations for warmup
#     warmup_ratio=0.001, # The ratio of the starting learning rate used for warmup
#     min_lr=1e-07)

custom_data ={'structure_indices': [2],
 'image_size': 2048,
 'modeltype': 'instance segmentation',
 'object_based': False,
 'physical_tile_size': (0.0, 0.0),
 'project_type': 'dummy',
 'pyramid_level': -1,
 'datetime': '14/12/2021 11:49',
 'structures': 'Blutzelle',
 'objects_count': 3606,
 'model': 'maskrcnn',
 'files': {'File': ['14.1.jpg', '15.1.jpg'], 'Scene': [1, 1]}}


custom_data = {'structure_indices': [16, 17, 18, 19], 'image_size': 256, 'modeltype': 'instance segmentation', 'object_based': False, 'physical_tile_size': (113.19408504630164, 113.19408504630164), 'project_type': 'dummy', 'pyramid_level': -1, 'datetime': '01/12/2021 18:09', 'structures': 'Tumor Cells 0+, Tumor Cells 1+, Tumor Cells 2+, Tumor Cells 3+', 'objects_count': 31002, 'model': 'maskrcnn', 'files': {'File': ['05_.czi', '05_.czi', '05_.czi', '05_.czi'], 'Scene': [2, 2, 2, 2]}}
#custom_data = {'structure_indices': [2], 'image_size': 512, 'modeltype': 'instance segmentation', 'object_based': False, 'physical_tile_size': (113.19408504630164, 113.19408504630164), 'project_type': 'dummy', 'pyramid_level': -1, 'datetime': '01/12/2021 18:09', 'structures': 'Tumor Cells 0+, Tumor Cells 1+, Tumor Cells 2+, Tumor Cells 3+', 'objects_count': 31002, 'model': 'maskrcnn', 'files': {'File': ['05_.czi', '05_.czi', '05_.czi', '05_.czi'], 'Scene': [2, 2, 2, 2]}}
trainer = MMDetTrainer(nc, base_config, work_dir, batch_size, workers, dataroot,
                       max_per_image = 100, rpn_max_per_image = 2000,
                       load_from = load_from, epochs = 20,
                       img_scale = img_scale, eval_interval = 1,
                       class_agnostic = False, custom_data = custom_data)
# trainer.cfg.lr_config = dict(
#     policy='CosineAnnealing', # The policy of scheduler, also support CosineAnnealing, Cyclic, etc. Refer to details of supported LrUpdater from https://github.com/open-mmlab/mmcv/blob/master/mmcv/runner/hooks/lr_updater.py#L9.
#     by_epoch=False,
#     warmup='linear', # The warmup policy, also support `exp` and `constant`.
#     warmup_iters=500, # The number of iterations for warmup
#     warmup_ratio=0.001, # The ratio of the starting learning rate used for warmup
#     min_lr=1e-07)
#trainer.cfg.resume_from = resume_from
trainer.cfg.device ='cuda'
trainer.cfg.lr_config = dict(
    policy='step',
    warmup='linear',
    warmup_iters=4500,
    warmup_ratio=0.001,
    step=[10, 15])
trainer.train()
# Out:
# 2022-05-12 13:34:06,078 - mmdet - INFO - load checkpoint from http path: https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# 2022-05-12 13:34:06,164 - mmdet - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-05-12 13:34:06,175 - mmdet - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2022-05-12 13:34:06,178 - mmdet - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2022-05-12 13:34:06,255 - mmcv - INFO -
# backbone.patch_embed.projection.weight - torch.Size([96, 3, 4, 4]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,255 - mmcv - INFO -
# backbone.patch_embed.projection.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,256 - mmcv - INFO -
# backbone.patch_embed.norm.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,256 - mmcv - INFO -
# backbone.patch_embed.norm.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,257 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm1.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,257 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,257 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 3]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,258 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.qkv.weight - torch.Size([288, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,258 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.qkv.bias - torch.Size([288]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,258 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.proj.weight - torch.Size([96, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,259 - mmcv - INFO -
# backbone.stages.0.blocks.0.attn.w_msa.proj.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,259 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm2.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,259 - mmcv - INFO -
# backbone.stages.0.blocks.0.norm2.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,260 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.0.0.weight - torch.Size([384, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,260 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.0.0.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,261 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.1.weight - torch.Size([96, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,261 - mmcv - INFO -
# backbone.stages.0.blocks.0.ffn.layers.1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,263 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm1.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,263 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,263 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 3]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,264 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.qkv.weight - torch.Size([288, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,264 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.qkv.bias - torch.Size([288]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,264 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.proj.weight - torch.Size([96, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,265 - mmcv - INFO -
# backbone.stages.0.blocks.1.attn.w_msa.proj.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,265 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm2.weight - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,266 - mmcv - INFO -
# backbone.stages.0.blocks.1.norm2.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,266 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.0.0.weight - torch.Size([384, 96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,266 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.0.0.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,266 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.1.weight - torch.Size([96, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,267 - mmcv - INFO -
# backbone.stages.0.blocks.1.ffn.layers.1.bias - torch.Size([96]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,267 - mmcv - INFO -
# backbone.stages.0.downsample.norm.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,267 - mmcv - INFO -
# backbone.stages.0.downsample.norm.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,268 - mmcv - INFO -
# backbone.stages.0.downsample.reduction.weight - torch.Size([192, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,268 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm1.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,268 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,268 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 6]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,269 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.qkv.weight - torch.Size([576, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,269 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.qkv.bias - torch.Size([576]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,269 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.proj.weight - torch.Size([192, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,270 - mmcv - INFO -
# backbone.stages.1.blocks.0.attn.w_msa.proj.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,270 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm2.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,270 - mmcv - INFO -
# backbone.stages.1.blocks.0.norm2.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,271 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.0.0.weight - torch.Size([768, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
# 2022-05-12 13:34:06,271 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.0.0.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,271 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.1.weight - torch.Size([192, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,271 - mmcv - INFO -
# backbone.stages.1.blocks.0.ffn.layers.1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,272 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm1.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,272 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,274 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 6]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,274 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.qkv.weight - torch.Size([576, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,275 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.qkv.bias - torch.Size([576]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,275 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.proj.weight - torch.Size([192, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,275 - mmcv - INFO -
# backbone.stages.1.blocks.1.attn.w_msa.proj.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,276 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm2.weight - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,276 - mmcv - INFO -
# backbone.stages.1.blocks.1.norm2.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,277 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.0.0.weight - torch.Size([768, 192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,277 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.0.0.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,278 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.1.weight - torch.Size([192, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,278 - mmcv - INFO -
# backbone.stages.1.blocks.1.ffn.layers.1.bias - torch.Size([192]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,278 - mmcv - INFO -
# backbone.stages.1.downsample.norm.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,279 - mmcv - INFO -
# backbone.stages.1.downsample.norm.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,279 - mmcv - INFO -
# backbone.stages.1.downsample.reduction.weight - torch.Size([384, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,280 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,280 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,281 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,281 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,281 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,282 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,282 - mmcv - INFO -
# backbone.stages.2.blocks.0.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,282 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,282 - mmcv - INFO -
# backbone.stages.2.blocks.0.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,283 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,283 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,283 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,284 - mmcv - INFO -
# backbone.stages.2.blocks.0.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,284 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,285 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,286 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,286 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,286 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,286 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,287 - mmcv - INFO -
# backbone.stages.2.blocks.1.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,287 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,287 - mmcv - INFO -
# backbone.stages.2.blocks.1.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,288 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,288 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,288 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,288 - mmcv - INFO -
# backbone.stages.2.blocks.1.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,289 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,290 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
# 2022-05-12 13:34:06,290 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,290 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,291 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,291 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,291 - mmcv - INFO -
# backbone.stages.2.blocks.2.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,292 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,292 - mmcv - INFO -
# backbone.stages.2.blocks.2.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,292 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,293 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,293 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,293 - mmcv - INFO -
# backbone.stages.2.blocks.2.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,294 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,294 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,294 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,295 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,296 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,296 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,297 - mmcv - INFO -
# backbone.stages.2.blocks.3.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,297 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,297 - mmcv - INFO -
# backbone.stages.2.blocks.3.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,298 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,298 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,299 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,299 - mmcv - INFO -
# backbone.stages.2.blocks.3.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,300 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,300 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,300 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,301 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,301 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,301 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,301 - mmcv - INFO -
# backbone.stages.2.blocks.4.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,302 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,303 - mmcv - INFO -
# backbone.stages.2.blocks.4.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,303 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,304 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,304 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,304 - mmcv - INFO -
# backbone.stages.2.blocks.4.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,305 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm1.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,305 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,305 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table - torch.Size([169, 12]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,306 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.qkv.weight - torch.Size([1152, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,306 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.qkv.bias - torch.Size([1152]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,306 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.proj.weight - torch.Size([384, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,306 - mmcv - INFO -
# backbone.stages.2.blocks.5.attn.w_msa.proj.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,307 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm2.weight - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,307 - mmcv - INFO -
# backbone.stages.2.blocks.5.norm2.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,308 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.0.0.weight - torch.Size([1536, 384]):
# Initialized by user-defined `init_weights` in SwinTransformer
# 2022-05-12 13:34:06,308 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.0.0.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,309 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.1.weight - torch.Size([384, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,309 - mmcv - INFO -
# backbone.stages.2.blocks.5.ffn.layers.1.bias - torch.Size([384]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,310 - mmcv - INFO -
# backbone.stages.2.downsample.norm.weight - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,310 - mmcv - INFO -
# backbone.stages.2.downsample.norm.bias - torch.Size([1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,310 - mmcv - INFO -
# backbone.stages.2.downsample.reduction.weight - torch.Size([768, 1536]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,311 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm1.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,311 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,311 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.relative_position_bias_table - torch.Size([169, 24]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,312 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.qkv.weight - torch.Size([2304, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,312 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.qkv.bias - torch.Size([2304]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,313 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.proj.weight - torch.Size([768, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,313 - mmcv - INFO -
# backbone.stages.3.blocks.0.attn.w_msa.proj.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,314 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm2.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,314 - mmcv - INFO -
# backbone.stages.3.blocks.0.norm2.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,314 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.0.0.weight - torch.Size([3072, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,314 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.0.0.bias - torch.Size([3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,315 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.1.weight - torch.Size([768, 3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,315 - mmcv - INFO -
# backbone.stages.3.blocks.0.ffn.layers.1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,315 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm1.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,316 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,316 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.relative_position_bias_table - torch.Size([169, 24]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,317 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.qkv.weight - torch.Size([2304, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,317 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.qkv.bias - torch.Size([2304]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,317 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.proj.weight - torch.Size([768, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,317 - mmcv - INFO -
# backbone.stages.3.blocks.1.attn.w_msa.proj.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,318 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm2.weight - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,318 - mmcv - INFO -
# backbone.stages.3.blocks.1.norm2.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,318 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.0.0.weight - torch.Size([3072, 768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,319 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.0.0.bias - torch.Size([3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,320 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.1.weight - torch.Size([768, 3072]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,320 - mmcv - INFO -
# backbone.stages.3.blocks.1.ffn.layers.1.bias - torch.Size([768]):
# Initialized by user-defined `init_weights` in SwinTransformer
#
# 2022-05-12 13:34:06,320 - mmcv - INFO -
# backbone.norm0.weight - torch.Size([96]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,321 - mmcv - INFO -
# backbone.norm0.bias - torch.Size([96]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,321 - mmcv - INFO -
# backbone.norm1.weight - torch.Size([192]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,321 - mmcv - INFO -
# backbone.norm1.bias - torch.Size([192]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,321 - mmcv - INFO -
# backbone.norm2.weight - torch.Size([384]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,322 - mmcv - INFO -
# backbone.norm2.bias - torch.Size([384]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,323 - mmcv - INFO -
# backbone.norm3.weight - torch.Size([768]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,323 - mmcv - INFO -
# backbone.norm3.bias - torch.Size([768]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,323 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 96, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,324 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,324 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 192, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,325 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,325 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 384, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,326 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,326 - mmcv - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 768, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,326 - mmcv - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
# 2022-05-12 13:34:06,327 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,327 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,327 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,328 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,328 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,328 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,329 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,329 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,329 - mmcv - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,330 - mmcv - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,330 - mmcv - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,330 - mmcv - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,330 - mmcv - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,331 - mmcv - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,331 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.weight - torch.Size([2, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,331 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.bias - torch.Size([2]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-05-12 13:34:06,332 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.weight - torch.Size([4, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-05-12 13:34:06,333 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-05-12 13:34:06,334 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,334 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,334 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,334 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-05-12 13:34:06,335 - mmcv - INFO -
# roi_head.mask_head.convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2022-05-12 13:34:06,335 - mmcv - INFO -
# roi_head.mask_head.convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,336 - mmcv - INFO -
# roi_head.mask_head.convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2022-05-12 13:34:06,336 - mmcv - INFO -
# roi_head.mask_head.convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,336 - mmcv - INFO -
# roi_head.mask_head.convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2022-05-12 13:34:06,337 - mmcv - INFO -
# roi_head.mask_head.convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,337 - mmcv - INFO -
# roi_head.mask_head.convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2022-05-12 13:34:06,337 - mmcv - INFO -
# roi_head.mask_head.convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of MaskRCNN
#
# 2022-05-12 13:34:06,337 - mmcv - INFO -
# roi_head.mask_head.upsample.weight - torch.Size([256, 256, 2, 2]):
# Initialized by user-defined `init_weights` in FCNMaskHead
#
# 2022-05-12 13:34:06,338 - mmcv - INFO -
# roi_head.mask_head.upsample.bias - torch.Size([256]):
# Initialized by user-defined `init_weights` in FCNMaskHead
#
# 2022-05-12 13:34:06,339 - mmcv - INFO -
# roi_head.mask_head.conv_logits.weight - torch.Size([1, 256, 1, 1]):
# Initialized by user-defined `init_weights` in FCNMaskHead
#
# 2022-05-12 13:34:06,339 - mmcv - INFO -
# roi_head.mask_head.conv_logits.bias - torch.Size([1]):
# Initialized by user-defined `init_weights` in FCNMaskHead
# loading annotations into memory...
# Done (t=1.08s)
# creating index...
# index created!
# 2022-05-12 13:34:08,552 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-05-12 13:34:08,610 - mmdet - INFO - load checkpoint from local path: F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_37.pth
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# 2022-05-12 13:34:08,819 - mmdet - INFO - Start running, host: phili@DESKTOP-ULUV98S, work_dir: F:\source\repos\InferenceDL\Exp
# 2022-05-12 13:34:08,820 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-05-12 13:34:08,820 - mmdet - INFO - workflow: [('train', 1)], max: 20 epochs
# 2022-05-12 13:34:08,821 - mmdet - INFO - Checkpoints will be saved to F:\source\repos\InferenceDL\Exp by HardDiskBackend.
# C:\Users\phili\miniconda3\lib\site-packages\mmcv\runner\hooks\evaluation.py:222: UserWarning: runner.meta is None. Creating an empty one.
#   warnings.warn('runner.meta is None. Creating an empty one.')

# %%
get_configs()

# %%
from mmdet.core import AnchorGenerator

# %%
AnchorGenerator(scales = [8], ratios = [0.5, 1.0, 2.0], strides = [16, 32, 16, 32, 64])

# %%
trainer.cfg.model.rpn_head.anchor_generator

# %%
add_key(trainer.cfg.model.rpn_head.anchor_generator, "scales", "base_sizes", [32,64,128,256,512])

# %%
data = torch.load(r"F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_37.pth", map_location=torch.device("cpu"))
data['custom_data'] = custom_data
torch.save(data, os.path.join(r"F:\source\repos\InferenceDL\Exp", "tubulus.pt"))

# %%
is_key_present(trainer.cfg.evaluation, "save_best")

# %%
import os
import torch
bests = []
for file in os.listdir(r"F:\source\repos\InferenceDL"):
    if("best" in file):
        bests.append(file)
bests = sorted(bests, key = lambda x:int(x.split("epoch_")[-1].replace(".pth", "")))

# %%
data = torch.load(bests[-1])

# %%
data['custom_data'] = "xd"

# %%
trainer.cfg.dump("xd.py")

# %%
from mmcv import Config

# %%
cfg = Config.fromfile(base_config)

# %%
dict(trainer.cfg)

# %%
trainer.train()

# %%
trainer.cfg.num_proposals = 750

# %%
dict(trainer.cfg)

# %%
dict(cfg)

# %%
trainer.cfg.optimizer_config = dict(grad_clip=dict(max_norm=35, norm_type=1))

# %%
trainer.cfg.resume_from = r"F:\source\repos\InferenceDL\latest.pth"

# %%
config_file = r"F:\source\repos\InferenceDL\Exp\config.py"
checkpoint_file = r"F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_17.pth"
model = InferenceModel(config_file, checkpoint_file)

# %%
model(r"C:\Users\phili\Downloads\Telegram Desktop\ValentinNeueBilder\dataset\valid\images\26922354.9.20MIB1_0s_0r_1008x_1680y_.png")

# %%
model = torch.load(r"F:\source\repos\InferenceDL\Exp\best_bbox_mAP_epoch_6.pth")

# %%
model['custom_data'] = {"structure_indices" : [2], "image_size": 2048, "object_based" : False}

# %%
torch.save(model, "")

# %%
img = cv2.imread(r"F:\source\repos\YOLOX\datasets\valentin128\train2017\26922354.9.20MIB1_0s_0r_336x_336y_.png") #bgr

# %%
result = model(img)

# %%
result.s

# %%
#D:\Hsa\temp\projects\addcf8c0-35b4-4df5-820b-54fe510357bc\dataset\train\images\ANCA_057_PAS_1s_0r_992x_1984y_.png
#D:\Hsa\temp\projects\addcf8c0-35b4-4df5-820b-54fe510357bc\dataset\train\images\ANCA_057_PAS_1s_0r_3968x_1984y_.png
img = cv2.imread(r"F:\source\repos\Daten\Her2Final\val2017\05__1s_0r_3120x_1680y_.png") #bgr 
#img = cv2.resize(img, (512, 512), interpolation = cv2.INTER_AREA)
result = model(img)
colors = [(255,0,0), (0,255,0), (0,0,255), (255,255,255)]
candidates = []

threshold = 0.15
empty = np.zeros((256, 256, 3))
for i in range(len(result[0])):
    for res, seg in zip(result[0][i], result[1][i]):
        bbox = res[:4].astype(int)
        score = res[4].astype(float)
        #print(score)
        if score < threshold:
            continue
        pts = np.where(seg.astype(float) > 0)
        candidates.append((score, bbox,pts, i))
        
        #if np.count_nonzero(empty[pts[0], pts[1]]) <= 0:
        #cv2.rectangle(empty, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color = 255, thickness = 1)
        #empty[pts[0], pts[1]] = colors[i]
            
#candidates.sort(key=lambda x: x[0], reverse = True)




bboxs=[]
for cand in candidates:
    score = cand[0]
    bbox = cand[1]
    pts = cand[2]
    
    cls = cand[3]
    def check_box(y,x, size = 2):
        if np.count_nonzero(empty[y-size:y+size, x-size:x+size]) != 0:
            return False
        return True
    to_add = []
    for y, x in zip(pts[0], pts[1]):
        if(check_box(y,x)):
            to_add.append((y,x))
    for y,x in to_add:
        empty[y,x] = colors[cls]
    bboxs.append(((bbox[0], bbox[1]), (bbox[2], bbox[3])))
# for a,b in bboxs:
#     cv2.rectangle(empty, a, b, color = (255,255,255), thickness = 1)
cv2.imwrite("xd4.png", empty)

# %%
print(list(map(lambda x: x[0], candidates)))

# %%
import numpy as np
np.array(result).shape

# %%
len(np.array(result).shape) == 1 # 2 is instance seg

# %%
img = cv2.imread(r"F:\source\repos\YOLOX\datasets\her2\train2017\06__1s_3r_1888x_1416y_.png") #bgr 
result = model(img)
colors = [(255,0,0), (0,255,0), (0,0,255), (255,255,255)]
to_draw = img.copy()
threshold = 0.25

for i in range(len(result)):
    for res in result[i]:
        bbox = res[:4].astype(int)
        score = res[4].astype(float)
        if score < threshold:
            continue
        cv2.rectangle(to_draw, (bbox[0], bbox[1]), (bbox[2], bbox[3]), color = colors[i], thickness = 1)
cv2.imwrite(os.path.join(work_dir, "xd.png"), to_draw)

# %%
import cv2
import os
import numpy as np

# %%
folder = r"F:\source\repos\Daten\Glomeruli\trainer\labels"

# %%
for file in os.listdir(folder):
    im = cv2.imread(os.path.join(folder, file), 0)
    im[im > 0] = 255
#     assert np.max(im) <= 1, f"not for {file}"
#     if file == "5483190_tile46x9.jpg":
#         print(np.max(im))
    cv2.imwrite(os.path.join(folder, file), im)

# %%
for file in os.listdir(folder):
    im = cv2.imread(os.path.join(folder, file), 0)
    if np.max(im) > 1:
        print(file)

# %%
im = cv2.imread(os.path.join(folder, "5483190_tile46x9.jpg"), 0)

# %%
im = np.ones((256,256))

# %%
np.max(im)

# %%
im[im > 0] = 1

# %%
im[im > 0] = 0

# %%
im.max()

# %%
im = cv2.imread(os.path.join(folder, "5483190_tile46x9.jpg"), 0)
im[im > 0.0] = 1.0

# %%
cv2.imwrite(os.path.join(r"F:\source\repos\YOLOX", "xd.jpg"), im)

# %%
cv2.imread(os.path.join(r"F:\source\repos\YOLOX", "xd.jpg"), 0).max()

# %%
im
